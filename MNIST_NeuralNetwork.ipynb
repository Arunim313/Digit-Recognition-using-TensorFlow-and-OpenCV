# %% [markdown]
# <a href="https://colab.research.google.com/github/Arunim313/MNIST_NeuralNetwork/blob/main/MNIST_NeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
x_train = tf.keras.utils.normalize(X_train, axis=1)
x_test = tf.keras.utils.normalize(X_test, axis=1)

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0264 - accuracy: 0.9952
# Epoch 2/20
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0235 - accuracy: 0.9955
# Epoch 3/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0262 - accuracy: 0.9947
# Epoch 4/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0226 - accuracy: 0.9951
# Epoch 5/20
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0197 - accuracy: 0.9959
# Epoch 6/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0178 - accuracy: 0.9961
# Epoch 7/20
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0165 - accuracy: 0.9963
# Epoch 8/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0194 - accuracy: 0.9956
# Epoch 9/20
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0149 - accuracy: 0.9972
# Epoch 10/20
# ...

# %%
model.save('digit_recognition.model')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 128)               100480
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 10)                650
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_8 (Dense)             (None, 128)               1408
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dense_10 (Dense)            (None, 10)                1290
#
# ...
# Total params: 145108 (566.83 KB)
# Trainable params: 145108 (566.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1523 - accuracy: 0.9785
# [0.15225251019001007, 0.9785000085830688]

# %%
img = cv2.imread('img3.png')[:,:,0]
img = np.invert(np.array([img]))
prediction = model.predict(img)
print(f"digit is {np.argmax(prediction)}")

plt.imshow(img[0], cmap=plt.cm.binary)
plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# digit is 9

# %%
img = cv2.imread('img10.png')[:,:,0]
img = np.invert(np.array([img]))
prediction = model.predict(img)
print(f"digit is {np.argmax(prediction)}")

plt.imshow(img[0], cmap=plt.cm.binary)
plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# digit is 0

# %%
img = cv2.imread('img2.png')[:,:,0]
img = np.invert(np.array([img]))
prediction = model.predict(img)
print(f"digit is {np.argmax(prediction)}")

plt.imshow(img[0], cmap=plt.cm.binary)
plt.show()
# Out:
# 1/1 [==============================] - 0s 29ms/step
# digit is 5

# %%
img = cv2.imread('img8.png')[:,:,0]
img = np.invert(np.array([img]))
prediction = model.predict(img)
print(f"digit is {np.argmax(prediction)}")

plt.imshow(img[0], cmap=plt.cm.binary)
plt.show()
# Out:
# 1/1 [==============================] - 0s 39ms/step
# digit is 4

# %%
img_number = 1

while os.path.isfile(f'/content/img{img_number}.png'):
  try:
    img = cv2.imread(f'img{img_number}.png')[:,:,0]
    img = np.invert(np.array([img]))
    prediction = model.predict(img)
    print(f"Image name is img{img_number}")
    print(f"Predicted digit is {np.argmax(prediction)}")
    plt.imshow(img[0], cmap=plt.cm.binary)
    plt.show()
    plt.close()
  except:
    print('Error')
  finally:
    img_number += 1
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Image name is img1
# Predicted digit is 7
# 1/1 [==============================] - 0s 111ms/step
# Image name is img2
# Predicted digit is 5
# 1/1 [==============================] - 0s 88ms/step
# Image name is img3
# Predicted digit is 9
# 1/1 [==============================] - 0s 72ms/step
# Image name is img4
# Predicted digit is 3
# 1/1 [==============================] - 0s 37ms/step
# Image name is img5
# Predicted digit is 5
# 1/1 [==============================] - 0s 34ms/step
# Image name is img6
# Predicted digit is 5
# 1/1 [==============================] - 0s 31ms/step
# Image name is img7
# Predicted digit is 8
# 1/1 [==============================] - 0s 43ms/step
# Image name is img8
# Predicted digit is 4
# 1/1 [==============================] - 0s 33ms/step
# Image name is img9
# Predicted digit is 1
# 1/1 [==============================] - 0s 40ms/step
# Image name is img10
# Predicted digit is 0
# ...
